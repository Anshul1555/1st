# %%
my_list[1,2,3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3j/061yd5kj65s8_6rjk5szl5kw0000gn/T/ipykernel_81901/532591313.py in <module>
# ----> 1 my_list[1,2,3]
#
# NameError: name 'my_list' is not defined

# %%
my_list = [1,2,3,'str']

# %%
my_list
# Out:
# [1, 2, 3, 'str']

# %%
my_list + ['new item']
# Out:
# [1, 2, 3, 'str', 'new item']

# %%
my_list * 2
# Out:
# [1, 2, 3, 'str', 1, 2, 3, 'str']

# %%
my_list.pop(0)
# Out:
# 1

# %%
my_list
# Out:
# [2, 3, 'str']

# %%
my_list.reversed()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3j/061yd5kj65s8_6rjk5szl5kw0000gn/T/ipykernel_81901/4079638353.py in <module>
# ----> 1 my_list.reversed()
#
# AttributeError: 'list' object has no attribute 'reversed'

# %%
my_list
# Out:
# [2, 3, 'str']

# %%
dic = {'ke1': 1, "ke2" : 2 }

# %%
dic
# Out:
# {'ke1': 1, 'ke2': 2}

# %%
dic["ke2"]
# Out:
# 2

# %%
dic2 = {"k1": 1, "k2" : [1,2,3]}

# %%
dic2
# Out:
# {'k1': 1, 'k2': [1, 2, 3]}

# %%
dic["k2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3j/061yd5kj65s8_6rjk5szl5kw0000gn/T/ipykernel_81901/2357790768.py in <module>
# ----> 1 dic["k2"]
#
# KeyError: 'k2'

# %%
dic2["k2"][2]
# Out:
# 3

# %%
dic2['k2'] = dic2['k2'] - 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3j/061yd5kj65s8_6rjk5szl5kw0000gn/T/ipykernel_81901/674803917.py in <module>
# ----> 1 dic2['k2'] = dic2['k2'] - 123
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
my_1 = {'k1' : 123}

# %%
my_1['k1'] = my_1['k1'] - 123

# %%
my_1['k1']
# Out:
# 0

# %%
d = {}

# %%
d
# Out:
# {}

# %%
d['ani'] = 1

# %%
d
# Out:
# {'ani': 1}

# %%
d['ani'] = 2

# %%
d
# Out:
# {'ani': 2}

# %%
e = {'ke1' : {"kw1" : {"ke2": 345}}}

# %%
e
# Out:
# {'ke1': {'kw1': {'ke2': 345}}}

# %%
e['ke1']['kw1']['ke2']
# Out:
# 345

# %%
e.keys()
# Out:
# dict_keys(['ke1'])

# %%
dic2.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
dic2.items()
# Out:
# dict_items([('k1', 1), ('k2', [1, 2, 3])])

# %%
if 1<2 :
    print("yes")
# Out:
# yes

# %%
if 1 > 2:
    print(2)
elif 2 < 3:
    print(12)
else : 
    print(34)
# Out:
# 12

# %%
seq = [1,2,3]

# %%
seq
# Out:
# [1, 2, 3]

# %%
for i in seq:
    print('i')
# Out:
# i
# i
# i

# %%
(1<2) and (2<3)
# Out:
# True

# %%
true is true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3j/061yd5kj65s8_6rjk5szl5kw0000gn/T/ipykernel_81901/483251937.py in <module>
# ----> 1 true is true
#
# NameError: name 'true' is not defined

# %%
True  - False
# Out:
# 1

# %% [raw]
# True and False or False

# %%
False and False or True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(dic)
# Out:
# dict

# %%
False and True or False
# Out:
# False

# %%
a = 2

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
a = True + True + True + 2 - False

b = 5*(True) + False

print("A") if a > b else print("None") if a == b else print("B")
# Out:
# None

# %%
True + True
# Out:
# 2

# %%
True - False
# Out:
# 1
